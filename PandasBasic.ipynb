# %% [markdown]
# <a href="https://colab.research.google.com/github/shubham25091998/machine_learning/blob/main/PandasBasic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
data = [10,20,30]
arr = np.array(data)
d = {'a':10,'b':20,'c':30}

# %%
# creating panda series with default label
pd.Series(data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
# panda series with custom lebel
pd.Series(data, index = labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# creating panda series with numpy array
pd.Series(arr,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#creating panda series with dictionary

# Key as labels & value as data
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# Dataframe

row_name = ['A','B','C','D']
col_name = ['W','X','Y','Z']

mydata = pd.DataFrame(np.random.randn(4,4),row_name,col_name)
# Out:
#           W         X         Y         Z
# A  0.319499 -0.906215 -1.739540  0.820980
# B  2.384555  0.849181 -0.523774  1.613747
# C  1.361598  0.528154  0.160206 -0.256498
# D  0.036065  1.781784 -2.132566  1.055614

# %%
mydata
# Out:
#           W         X         Y         Z
# A  0.319499 -0.906215 -1.739540  0.820980
# B  2.384555  0.849181 -0.523774  1.613747
# C  1.361598  0.528154  0.160206 -0.256498
# D  0.036065  1.781784 -2.132566  1.055614

# %%
# access column from dataframe
# Each column is a panda series
mydata['W']
# Out:
# A    0.319499
# B    2.384555
# C    1.361598
# D    0.036065
# Name: W, dtype: float64

# %%
# adding new column
mydata['New'] = np.random.randint(1,4,4)
mydata
# Out:
#           W         X         Y         Z  New
# A  0.319499 -0.906215 -1.739540  0.820980    1
# B  2.384555  0.849181 -0.523774  1.613747    2
# C  1.361598  0.528154  0.160206 -0.256498    3
# D  0.036065  1.781784 -2.132566  1.055614    1

# %%
# remove column
# bydefault axis = 0 (i.e. row) is defined
# axis = 1 for column
# inplace to make changes in original data
mydata.drop(["New"],axis = 1, inplace = True)
mydata
# Out:
#           W         X         Y         Z
# A  0.319499 -0.906215 -1.739540  0.820980
# B  2.384555  0.849181 -0.523774  1.613747
# C  1.361598  0.528154  0.160206 -0.256498
# D  0.036065  1.781784 -2.132566  1.055614

# %%
# remove row
mydata.drop(["D"], axis = 0, inplace = True)
mydata
# Out:
#           W         X         Y         Z
# A  0.319499 -0.906215 -1.739540  0.820980
# B  2.384555  0.849181 -0.523774  1.613747
# C  1.361598  0.528154  0.160206 -0.256498

# %%
# access row using row label
mydata.loc['B']
# Out:
# W    2.384555
# X    0.849181
# Y   -0.523774
# Z    1.613747
# Name: B, dtype: float64

# %%
# access row by index
mydata.iloc[1]
# Out:
# W    2.384555
# X    0.849181
# Y   -0.523774
# Z    1.613747
# Name: B, dtype: float64

# %%
mydata.loc[['A','B'],['Y','Z']]
# Out:
#           Y         Z
# A -1.739540  0.820980
# B -0.523774  1.613747

# %%
mydata
# Out:
#           W         X         Y         Z
# A  0.319499 -0.906215 -1.739540  0.820980
# B  2.384555  0.849181 -0.523774  1.613747
# C  1.361598  0.528154  0.160206 -0.256498

# %%
mydata > 0
# Out:
#       W      X      Y      Z
# A  True  False  False   True
# B  True   True  False   True
# C  True   True   True  False

# %%
# where condition is false those data will appear as NaN
mydata[mydata>0]
# Out:
#           W         X         Y         Z
# A  0.319499       NaN       NaN  0.820980
# B  2.384555  0.849181       NaN  1.613747
# C  1.361598  0.528154  0.160206       NaN

# %%
# apply condition to certain column and do not print that column to avoid NaN value
# here the row from column X which is not satisfing the condition will not be printed
mydata[mydata['X'] > 0]
# Out:
#           W         X         Y         Z
# B  2.384555  0.849181 -0.523774  1.613747
# C  1.361598  0.528154  0.160206 -0.256498

# %%
# using and/or condition

# & (normal and operator does not work on list of boolean)
print(mydata[ (mydata['Y'] > 0) & (mydata['Z'] < 0)])

# | (or)
print(mydata[ (mydata['Y'] > 0) | (mydata['W'] > 0)])
# Out:
#           W         X         Y         Z
# C  1.361598  0.528154  0.160206 -0.256498
#           W         X         Y         Z
# A  0.319499 -0.906215 -1.739540  0.820980
# B  2.384555  0.849181 -0.523774  1.613747
# C  1.361598  0.528154  0.160206 -0.256498

# %%
# resetting index
print(mydata)

# by default reset index has inplace = false
mydata.reset_index()
# Out:
#           W         X         Y         Z
# A  0.319499 -0.906215 -1.739540  0.820980
# B  2.384555  0.849181 -0.523774  1.613747
# C  1.361598  0.528154  0.160206 -0.256498
#   index         W         X         Y         Z
# 0     A  0.319499 -0.906215 -1.739540  0.820980
# 1     B  2.384555  0.849181 -0.523774  1.613747
# 2     C  1.361598  0.528154  0.160206 -0.256498

# %%
# setting another column as index
new_index = "L M N".split()
print(new_index)

mydata['New_Index'] = new_index
mydata.set_index("New_Index")
# Out:
# ['L', 'M', 'N']
#                   W         X         Y         Z
# New_Index
# L          0.319499 -0.906215 -1.739540  0.820980
# M          2.384555  0.849181 -0.523774  1.613747
# N          1.361598  0.528154  0.160206 -0.256498

# %%
# multi-level indexed dataframe

lvl1 = "G1 G1 G1 G2 G2 G2".split()
lvl2 = [1,2,3,1,2,3]

row_ind = list(zip(lvl1,lvl2))
row_ind = pd.MultiIndex.from_tuples(row_ind)

# %%
data = pd.DataFrame(np.random.rand(6,3),row_ind,[1,2,3])
data
# Out:
#              1         2         3
# G1 1  0.593540  0.135261  0.794443
#    2  0.774287  0.732697  0.906067
#    3  0.324258  0.752460  0.267281
# G2 1  0.873244  0.432261  0.446910
#    2  0.306728  0.879751  0.846469
#    3  0.334644  0.562747  0.391222

# %%
# provide names to row indexs

data.index.names

data.index.names = ['Group','Sr.No.']
data
# Out:
#                      1         2         3
# Group Sr.No.
# G1    1       0.593540  0.135261  0.794443
#       2       0.774287  0.732697  0.906067
#       3       0.324258  0.752460  0.267281
# G2    1       0.873244  0.432261  0.446910
#       2       0.306728  0.879751  0.846469
#       3       0.334644  0.562747  0.391222

# %%
# accessing data from multi-level index
data.loc['G1'].loc[1]
# Out:
# 1    0.593540
# 2    0.135261
# 3    0.794443
# Name: 1, dtype: float64
